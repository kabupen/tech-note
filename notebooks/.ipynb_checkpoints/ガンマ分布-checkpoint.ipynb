# %%
import numpy as np
import matplotlib.pyplot as plt

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import gamma

# %%
# グラフの描画
fig, ax = plt.subplots(figsize=(8, 5))

for alpha in [1, 5, 10]:
    # ガンマ分布のパラメータ
    shape = alpha  # 形状パラメータ (k)
    scale = 1  # 尺度パラメータ (θ)
    
    # x 軸の値を生成
    x = np.linspace(0, 20, 1000)
    
    # ガンマ分布の確率密度関数 (PDF) を計算
    pdf = gamma.pdf(x, a=shape, scale=scale)
    ax.plot(x, pdf, label=f'Gamma (shape={shape}, scale={scale})')
    
ax.set_title('Gamma Distribution')
ax.set_xlabel('x')
ax.set_ylabel('Probability Density')
ax.legend()
# ax.grid(True)

plt.show()
